# %% [markdown]
# <a href="https://colab.research.google.com/github/lindsayydevine/Exercise_1/blob/main/520_Exercise_1_Submission.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# %pip install evaluate tabulate

# %%
import os
os.environ["HF_ALLOW_CODE_EVAL"] = "1"
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %%
import torch
import gc
from datasets import load_dataset
from evaluate import load
from transformers import AutoModelForCausalLM, AutoTokenizer
from tabulate import tabulate
from tqdm import tqdm

# Mapping model names to human-readable labels
model_label_map = {
    "Solshine/Meta-Llama-3.1-8B-Instruct-Python-Coder": "LLaMa",
    "lmsys/vicuna-13b-v1.5": "Vicuna"
}

model_names = list(model_label_map.keys())
prompt_strategies = ["Chain of Thought", "Self-Debugging"]

# Storage for all generations
all_generations_table = []
results_all = []

for model_name in model_names:
    for prompt_strategy in prompt_strategies:
        # Load the code evaluation metric
        code_eval = load("code_eval")

        # Load tokenizer and model
        print(f"\nLoading model: {model_label_map[model_name]}")
        tokenizer = AutoTokenizer.from_pretrained(model_name)

        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

        model = AutoModelForCausalLM.from_pretrained(model_name).to(device)
        model.eval()

        results_table = []

        for i in tqdm(range(10), desc="Problems"):
            human_eval_indiv_problem = load_dataset("openai_humaneval")['test'].select([i])
            num_samples_per_problem = 3

            test_cases = []
            candidates = []

            for problem in human_eval_indiv_problem:
                entry_point = problem['entry_point']
                test_code = problem['test']
                problem_prompt = problem['prompt']

                if prompt_strategy == "Raw":
                  prompt = problem['prompt']

                elif prompt_strategy == "Chain of Thought":
                    prompt = f"""
                      \"\"\"
                      Write a clean, compilable Python function named `{problem['entry_point']}` that takes in the arguments and import statements described and solves the problem below.

                      {problem['prompt']}

                      Include listed steps for solving the code implementation in a docstring.
                      \"\"\"

                      Return the steps followed by final completed function definition and must include all imports from {problem['prompt']}:

                      from typing import List
                      def {problem['entry_point']}(
                      """

                elif prompt_strategy == "Self-Debugging":
                    prompt = f"""
                      \"\"\"
                      Write a clean, compilable Python function named `{problem['entry_point']}` that takes in the arguments and import statements described and solves the problem below.

                      {problem['prompt']}

                      Debug the code and fix any errors or missing parts. Check that all indentation is appropriate so that code is compilable without errors.
                      \"\"\"

                      Return the final completed fixed function definition and must include all imports from {problem['prompt']}:

                      from typing import List
                      def {problem['entry_point']}(
                      """

                test_cases.append(test_code)
                problem_candidates = []

                for _ in range(num_samples_per_problem):
                    inputs = tokenizer(prompt, return_tensors="pt").to(device)
                    input_len = inputs["input_ids"].shape[1]

                    with torch.no_grad():
                        outputs = model.generate(
                            input_ids=inputs["input_ids"],
                            attention_mask=inputs["attention_mask"],
                            max_new_tokens=256,
                            temperature=0.7,
                            top_p=0.95,
                            do_sample=True,
                            eos_token_id=tokenizer.eos_token_id
                        )

                    generated_ids = outputs[0][input_len:]
                    generated_code = tokenizer.decode(generated_ids, skip_special_tokens=True)

                    full_code = f"def {entry_point}(" + generated_code
                    problem_candidates.append(full_code)

                candidates.append(problem_candidates)

                # Store the generations
                all_generations_table.append({
                    "Problem ID": i + 1,
                    "LLM": model_label_map[model_name],
                    "Prompt Type": prompt_strategy,
                    "Gen 1": problem_candidates[0],
                    "Gen 2": problem_candidates[1],
                    "Gen 3": problem_candidates[2]
                })

                # Memory cleanup after each problem
                torch.cuda.empty_cache()
                gc.collect()
                torch.cuda.ipc_collect()

        print("Code generation complete. Evaluating...")

        # Evaluate the generated code
        k_values = [1, 3]

        print(test_cases)
        print(candidates)

        pass_at_k, results = code_eval.compute(
            references=test_cases,
            predictions=candidates,
            k=k_values,
            num_workers=2,
            timeout=10.0
        )

        results_all.append(results)

        for k in k_values:
            print(f"Pass@{k}: {pass_at_k[f'pass@{k}'] * 100:.2f}%")
            print(f"Results for Pass@{k}:{results}")

        results_table.append({
            "Problem ID": i + 1,
            "Pass@1": round(pass_at_k["pass@1"] * 100, 2),
            "Pass@3": round(pass_at_k["pass@3"] * 100, 2)
        })

        # Delete model before loading the next one
        del model
        del tokenizer
        torch.cuda.empty_cache()
        gc.collect()

        print("\n=== Pass@k Results Summary ===")
        print(tabulate(results_table, headers="keys", tablefmt="grid"))
# Out:
# Loading model: LLaMa
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Problems: 100%|██████████| 10/10 [03:35<00:00, 21.52s/it]
# Code generation complete. Evaluating...
# ["\n\nMETADATA = {\n    'author': 'jt',\n    'dataset': 'test'\n}\n\n\ndef check(candidate):\n    assert candidate([]) == []\n    assert candidate([1, 2, 3, 4]) == [1, 2, 3, 4]\n    assert candidate([4, 3, 2, 1]) == [4, 4, 4, 4]\n    assert candidate([3, 2, 3, 100, 3]) == [3, 3, 3, 100, 100]\n"]
# [['def rolling_max( numbers: List[int]\n                      ) -> List[int]:\n    rmax = numbers[0]\n    max_numbers = [rmax]\n    for number in numbers[1:]:\n        if number >= rmax:\n            rmax = number\n        max_numbers.append(rmax)\n    return max_numbers\n                      ', 'def rolling_max( numbers: List[int]) -> List[int]:\n    # Initialize a list to store the rolling maximum values, with the first value set to the first element of the input list.\n    rolling_max_values = [numbers[0]]\n    # Iterate over the input list starting from the second element.\n    for i in range(1, len(numbers)):\n        # For each element, check if it is greater than the last rolling maximum value. If it is, update the rolling maximum value.\n        if numbers[i] > rolling_max_values[-1]:\n            rolling_max_values.append(numbers[i])\n        # If the current element is not greater than the last rolling maximum value, keep the last rolling maximum value.\n        else:\n            rolling_max_values.append(rolling_max_values[-1])\n    return rolling_max_values\n\n', 'def rolling_max( numbers: List[int]) -> List[int]:\n                       """ From a given list of integers, generate a list of rolling maximum element found until given moment\n    in the sequence.\n    >>> rolling_max([1, 2, 3, 2, 3, 4, 2])\n    [1, 2, 3, 3, 3, 4, 4]\n    """\n                       answer = []\n                       for i in range(len(numbers)):\n                           answer.append(max(numbers[:i+1]))\n                       return answer\n                      <span class="hint">You can solve this problem by using a for loop, and in each iteration, find the maximum number from the numbers list until the current index.</span>']]
# Pass@1: 0.00%
# Results for Pass@1:defaultdict(<class 'list'>, {0: [(0, {'task_id': 0, 'passed': False, 'result': "failed: name 'List' is not defined", 'completion_id': 0}), (1, {'task_id': 0, 'passed': False, 'result': "failed: name 'List' is not defined", 'completion_id': 1}), (2, {'task_id': 0, 'passed': False, 'result': 'failed: unindent does not match any outer indentation level (<string>, line 11)', 'completion_id': 2})]})
# Pass@3: 0.00%
# Results for Pass@3:defaultdict(<class 'list'>, {0: [(0, {'task_id': 0, 'passed': False, 'result': "failed: name 'List' is not defined", 'completion_id': 0}), (1, {'task_id': 0, 'passed': False, 'result': "failed: name 'List' is not defined", 'completion_id': 1}), (2, {'task_id': 0, 'passed': False, 'result': 'failed: unindent does not match any outer indentation level (<string>, line 11)', 'completion_id': 2})]})
#
# === Pass@k Results Summary ===
# +--------------+----------+----------+
# |   Problem ID |   Pass@1 |   Pass@3 |
# +==============+==========+==========+
# |           10 |        0 |        0 |
# +--------------+----------+----------+
#
# Loading model: LLaMa
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Problems: 100%|██████████| 10/10 [02:54<00:00, 17.47s/it]
# Code generation complete. Evaluating...
# ["\n\nMETADATA = {\n    'author': 'jt',\n    'dataset': 'test'\n}\n\n\ndef check(candidate):\n    assert candidate([]) == []\n    assert candidate([1, 2, 3, 4]) == [1, 2, 3, 4]\n    assert candidate([4, 3, 2, 1]) == [4, 4, 4, 4]\n    assert candidate([3, 2, 3, 100, 3]) == [3, 3, 3, 100, 100]\n"]
# [['def rolling_max( numbers: List[int]\n                      ) -> List[int]:\n                        """ From a given list of integers, generate a list of rolling maximum element found until given moment\n                        in the sequence.\n                        >>> rolling_max([1, 2, 3, 2, 3, 4, 2])\n                        [1, 2, 3, 3, 3, 4, 4]\n                        """\n    max_num = float(\'-inf\')\n    max_nums = []\n    for num in numbers:\n        if num > max_num:\n            max_num = num\n        max_nums.append(max_num)\n    return max_nums\n                      \n\n                      This function works by initializing the maximum number to negative infinity and an empty list to store the maximum numbers. It then iterates over the input list, checking each number against the current maximum. If the number is greater, it updates the maximum number. The maximum number is then appended to the list of maximum numbers. This process continues until the end of the list, resulting in a list of rolling maximum numbers.\n                     ', 'def rolling_max( numbers: List[int]) -> List[int]:\n                          max_num = numbers[0]\n                          max_list = [max_num]\n                          for i in range(1, len(numbers)):\n                              if numbers[i] > max_num:\n                                  max_num = numbers[i]\n                                  max_list.append(max_num)\n                              else:\n                                  max_list.append(max_num)\n                          return max_list', 'def rolling_max( numbers: List[int]) -> List[int]:\n    """ From a given list of integers, generate a list of rolling maximum element found until given moment\n    in the sequence.\n    >>> rolling_max([1, 2, 3, 2, 3, 4, 2])\n    [1, 2, 3, 3, 3, 4, 4]\n    """\n    max_list = []\n    current_max = 0\n    for i in range(len(numbers)):\n        current_max = max(current_max, numbers[i])\n        max_list.append(current_max)\n    return max_list\n']]
# Pass@1: 0.00%
# Results for Pass@1:defaultdict(<class 'list'>, {0: [(0, {'task_id': 0, 'passed': False, 'result': 'failed: unindent does not match any outer indentation level (<string>, line 8)', 'completion_id': 0}), (1, {'task_id': 0, 'passed': False, 'result': "failed: name 'List' is not defined", 'completion_id': 1}), (2, {'task_id': 0, 'passed': False, 'result': "failed: name 'List' is not defined", 'completion_id': 2})]})
# Pass@3: 0.00%
# Results for Pass@3:defaultdict(<class 'list'>, {0: [(0, {'task_id': 0, 'passed': False, 'result': 'failed: unindent does not match any outer indentation level (<string>, line 8)', 'completion_id': 0}), (1, {'task_id': 0, 'passed': False, 'result': "failed: name 'List' is not defined", 'completion_id': 1}), (2, {'task_id': 0, 'passed': False, 'result': "failed: name 'List' is not defined", 'completion_id': 2})]})
#
# === Pass@k Results Summary ===
# +--------------+----------+----------+
# |   Problem ID |   Pass@1 |   Pass@3 |
# +==============+==========+==========+
# |           10 |        0 |        0 |
# +--------------+----------+----------+
#
# Loading model: Vicuna
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Problems:   0%|          | 0/10 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/transformers/generation/utils.py:1733: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed in v5. Please use and modify the model generation configuration (see https://huggingface.co/docs/transformers/generation_strategies#default-text-generation-configuration )
#   warnings.warn(
# Problems: 100%|██████████| 10/10 [04:43<00:00, 28.33s/it]
# Code generation complete. Evaluating...
# ["\n\nMETADATA = {\n    'author': 'jt',\n    'dataset': 'test'\n}\n\n\ndef check(candidate):\n    assert candidate([]) == []\n    assert candidate([1, 2, 3, 4]) == [1, 2, 3, 4]\n    assert candidate([4, 3, 2, 1]) == [4, 4, 4, 4]\n    assert candidate([3, 2, 3, 100, 3]) == [3, 3, 3, 100, 100]\n"]
# [['def rolling_max():', 'def rolling_max():\n                         \n                      :param numbers: a list of integers\n                      :return: a list of integers\n                      """\n                      numbers = numbers\n                      result = []\n                      max_so_far = numbers[0]\n                      for num in numbers[1:]:\n                          if num > max_so_far:\n                              max_so_far = num\n                          result.append(max_so_far)\n                      return result\n\n                      # check if the code is correct\n                      # print(rolling_max([1, 2, 3, 2, 3, 4, 2]))\n                      # print(rolling_max([5, 4, 3, 2, 1, 5, 4, 3, 2, 1]))\n\n                      return result\n\n                      # check if the code is correct\n                      # print(rolling_max([1, 2, 3, 2, 3, 4, 2]))\n                      # print(rolling_max([5, 4, 3, 2, 1,', 'def rolling_max():']]
# Pass@1: 0.00%
# Results for Pass@1:defaultdict(<class 'list'>, {0: [(0, {'task_id': 0, 'passed': False, 'result': 'failed: expected an indented block after function definition on line 1 (<string>, line 4)', 'completion_id': 0}), (1, {'task_id': 0, 'passed': False, 'result': 'failed: unterminated triple-quoted string literal (detected at line 36) (<string>, line 5)', 'completion_id': 1}), (2, {'task_id': 0, 'passed': False, 'result': 'failed: expected an indented block after function definition on line 1 (<string>, line 4)', 'completion_id': 2})]})
# Pass@3: 0.00%
# Results for Pass@3:defaultdict(<class 'list'>, {0: [(0, {'task_id': 0, 'passed': False, 'result': 'failed: expected an indented block after function definition on line 1 (<string>, line 4)', 'completion_id': 0}), (1, {'task_id': 0, 'passed': False, 'result': 'failed: unterminated triple-quoted string literal (detected at line 36) (<string>, line 5)', 'completion_id': 1}), (2, {'task_id': 0, 'passed': False, 'result': 'failed: expected an indented block after function definition on line 1 (<string>, line 4)', 'completion_id': 2})]})
#
# === Pass@k Results Summary ===
# +--------------+----------+----------+
# |   Problem ID |   Pass@1 |   Pass@3 |
# +==============+==========+==========+
# |           10 |        0 |        0 |
# +--------------+----------+----------+
#
# Loading model: Vicuna
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Problems: 100%|██████████| 10/10 [04:23<00:00, 26.36s/it]
# Code generation complete. Evaluating...
# ["\n\nMETADATA = {\n    'author': 'jt',\n    'dataset': 'test'\n}\n\n\ndef check(candidate):\n    assert candidate([]) == []\n    assert candidate([1, 2, 3, 4]) == [1, 2, 3, 4]\n    assert candidate([4, 3, 2, 1]) == [4, 4, 4, 4]\n    assert candidate([3, 2, 3, 100, 3]) == [3, 3, 3, 100, 100]\n"]
# [['def rolling_max():', 'def rolling_max():\n                          :\n\n                      from typing import List, Tuple\n                      def rolling\\_max(numbers: List[int]) -> List[int]:\n                          :\n\n                      from typing import List\n                      def rolling\\_max(\n                      ):\n                          :\n\n                      from typing import List, Tuple\n                      def rolling\\_max(numbers: List[int]) -> List[int]:\n                          :\n\n                      from typing import List\n                      def rolling\\_max(\n                      ):\n                          :\n\n                      from typing import List, Tuple\n                      def rolling\\_max(numbers: List[int]) -> List[int]:\n                          :\n\n                      from typing import List, Tuple\n                      def rolling\\_max(numbers: List[int]) -> List[int]:\n                          :\n\n                      from typing import List\n                      def rolling\\_max(\n                      ):\n                          :\n\n                      from typing import List, Tuple\n                      def rolling\\_max(numbers: List[int]) -> List[int]:\n                          :\n\n                      from typing import List,', 'def rolling_max():\n                         \n                        \n                      from typing import List, Tuple\n                      def rolling\\_max(numbers: List[int]) -> List[int]:\n                         \n                        \n                        \n                      from typing import List, Tuple\n                      def rolling\\_max(numbers: List[int]) -> List[int]:\n                         \n                        \n                        \n                      from typing import List, Tuple\n                      def rolling\\_max(numbers: List[int]) -> List[int]:\n                         \n                        \n                        \n                      from typing import List, Tuple\n                      def rolling\\_max(numbers: List[int]) -> List[int]:\n                         \n                        \n                        \n                      from typing import List, Tuple\n                      def rolling\\_max(numbers: List[int]) -> List[int]:\n                         \n                        \n                        \n                      from typing import List, Tuple\n                      def rolling\\_max(numbers: List[int]) -> List[int]:\n                         \n                        \n                        \n                      from typing import List, Tuple\n                      def rolling\\_max(numbers: List']]
# Pass@1: 0.00%
# Results for Pass@1:defaultdict(<class 'list'>, {0: [(0, {'task_id': 0, 'passed': False, 'result': 'failed: expected an indented block after function definition on line 1 (<string>, line 4)', 'completion_id': 0}), (1, {'task_id': 0, 'passed': False, 'result': 'failed: invalid syntax (<string>, line 2)', 'completion_id': 1}), (2, {'task_id': 0, 'passed': False, 'result': 'failed: unexpected character after line continuation character (<string>, line 5)', 'completion_id': 2})]})
# Pass@3: 0.00%
# Results for Pass@3:defaultdict(<class 'list'>, {0: [(0, {'task_id': 0, 'passed': False, 'result': 'failed: expected an indented block after function definition on line 1 (<string>, line 4)', 'completion_id': 0}), (1, {'task_id': 0, 'passed': False, 'result': 'failed: invalid syntax (<string>, line 2)', 'completion_id': 1}), (2, {'task_id': 0, 'passed': False, 'result': 'failed: unexpected character after line continuation character (<string>, line 5)', 'completion_id': 2})]})
#
# === Pass@k Results Summary ===
# +--------------+----------+----------+
# |   Problem ID |   Pass@1 |   Pass@3 |
# +==============+==========+==========+
# |           10 |        0 |        0 |
# +--------------+----------+----------+

# %%
from tabulate import tabulate

print("\n=== All Generated Code Samples ===")
print(tabulate(all_generations_table, headers="keys", tablefmt="grid"))
# Out:
# === All Generated Code Samples ===
# +--------------+--------+------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   Problem ID | LLM    | Prompt Type      | Gen 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                | Gen 2                                                                                                                                                                                                                                                               | Gen 3                                                                                                                                                                                         |
# +==============+========+==================+======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================+=====================================================================================================================================================================================================================================================================+===============================================================================================================================================================================================+
# |            1 | LLaMa  | Chain of Thought | def has_close_elements( numbers: List[float], threshold: float) -> bool:                                                                                                                                                                                                                                                                                                                                                                                                             | def has_close_elements( numbers: List[float], threshold: float) -> bool:                                                                                                                                                                                            | def has_close_elements( numbers: List[float], threshold: float) -> bool:                                                                                                                      |
# |              |        |                  |     numbers.sort()                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |                                                                                                                                                                                                                                                                     |                                                                                                                                                                                               |
# |              |        |                  |     for i in range(1, len(numbers) - 1):                                                                                                                                                                                                                                                                                                                                                                                                                                             |                           numbers.sort()                                                                                                                                                                                                                            |     sorted_numbers = sorted(numbers)                                                                                                                                                          |
# |              |        |                  |         if numbers[i] - numbers[i - 1] < threshold and numbers[                                                                                                                                                                                                                                                                                                                                                                                                                      |                           for i in range(1, len(numbers) - 1):                                                                                                                                                                                                      |     for i in range(1, len(sorted_numbers)):                                                                                                                                                   |
# |              |        |                  |             i + 1] - numbers[i] < threshold:                                                                                                                                                                                                                                                                                                                                                                                                                                         |                               if abs(numbers[i] - numbers[i - 1]) <= threshold:                                                                                                                                                                                     |         if abs(sorted_numbers[i] - sorted_numbers[i - 1]) < threshold:                                                                                                                        |
# |              |        |                  |             return True                                                                                                                                                                                                                                                                                                                                                                                                                                                              |                                   return True                                                                                                                                                                                                                       |             return True                                                                                                                                                                       |
# |              |        |                  |     return False                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |                           return False                                                                                                                                                                                                                              |     return False                                                                                                                                                                              |
# |              |        |                  |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |                       return has_close_elements                                                                                                                                                                                                                     |                                                                                                                                                                                               |
# +--------------+--------+------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |            2 | LLaMa  | Chain of Thought | def separate_paren_groups( paren_string: str) -> List[str]:                                                                                                                                                                                                                                                                                                                                                                                                                          | def separate_paren_groups( ) -> List[str]:  # type: ignore                                                                                                                                                                                                          | def separate_paren_groups( paren_string: str                                                                                                                                                  |
# |              |        |                  |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |     # Define a function `separate_paren_groups` that takes a string of parentheses as input and returns a list of strings, each representing a group of parentheses.                                                                                                |                        ) -> List[str]:                                                                                                                                                        |
# |              |        |                  |                           # Initialize an empty stack to store the opening parentheses                                                                                                                                                                                                                                                                                                                                                                                               |     stack = []  # Initialize an empty stack to keep track of the opening and closing parentheses.                                                                                                                                                                   |     stack = []                                                                                                                                                                                |
# |              |        |                  |                           opening_stack = []                                                                                                                                                                                                                                                                                                                                                                                                                                         |     groups = []  # Initialize an empty list to store the groups of parentheses.                                                                                                                                                                                     |     start_index = -1                                                                                                                                                                          |
# |              |        |                  |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |     start_group = 0  # Initialize a variable to store the start index of the current group.                                                                                                                                                                         |     temp = []                                                                                                                                                                                 |
# |              |        |                  |                           # Initialize an empty list to store the separate groups                                                                                                                                                                                                                                                                                                                                                                                                    |     for i, c in enumerate(paren_string):  # Iterate over the input string.                                                                                                                                                                                          |     for index, char in enumerate(paren_string):                                                                                                                                               |
# |              |        |                  |                           separate_groups = []                                                                                                                                                                                                                                                                                                                                                                                                                                       |         if c == '(':  # If the current character is an opening parenthesis.                                                                                                                                                                                         |         if char == '(':                                                                                                                                                                       |
# |              |        |                  |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |             stack.append(i)  # Push the current index onto the stack.                                                                                                                                                                                               |             stack.append(index)                                                                                                                                                               |
# |              |        |                  |                           # Initialize an empty string to build each group                                                                                                                                                                                                                                                                                                                                                                                                           |         elif c == ')':  # If the current character is a closing parenthesis.                                                                                                                                                                                        |         elif char == ')':                                                                                                                                                                     |
# |              |        |                  |                           group = ''                                                                                                                                                                                                                                                                                                                                                                                                                                                 |             if stack:  # If the stack is not empty.                                                                                                                                                                                                                 |             if stack:                                                                                                                                                                         |
# |              |        |                  |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |                 stack.pop()  # Pop the last opening parenthesis from the stack.                                                                                                                                                                                     |                 stack.pop()                                                                                                                                                                   |
# |              |        |                  |                           # Iterate over each character in the input string                                                                                                                                                                                                                                                                                                                                                                                                          |             if not stack:  # If the stack is empty.                                                                                                                                                                                                                 |             if stack:                                                                                                                                                                         |
# |              |        |                  |                           for char in paren_string:                                                                                                                                                                                                                                                                                                                                                                                                                                  |                 groups.append(paren_string[start_group:i+1])  # Add the current group to the list of groups.                                                                                                                                                        |                 temp.append('(')                                                                                                                                                              |
# |              |        |                  |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |                 start_group = i+1  # Update the start index of the current group.                                                                                                                                                                                   |             temp.append(')')                                                                                                                                                                  |
# |              |        |                  |                               # If the character is an opening parenthesis, push it to the stack                                                                                                                                                                                                                                                                                                                                                                                     |     return groups                                                                                                                                                                                                                                                   |             if not stack:                                                                                                                                                                     |
# |              |        |                  |                               if char == '(':                                                                                                                                                                                                                                                                                                                                                                                                                                        |                                                                                                                                                                                                                                                                     |                 start_index = index                                                                                                                                                           |
# |              |        |                  |                                   opening_stack.append(char)                                                                                                                                                                                                                                                                                                                                                                                                                         |                                                                                                                                                                                                                                                                     |     if start_index == -1:                                                                                                                                                                     |
# |              |        |                  |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |                                                                                                                                                                                                                                                                     |         return [paren_string]                                                                                                                                                                 |
# |              |        |                  |                                   # If the group is empty, start building it                                                                                                                                                                                                                                                                                                                                                                                                         |                                                                                                                                                                                                                                                                     |     if start_index == len(paren_string) - 1:                                                                                                                                                  |
# |              |        |                  |                                   if not group:                                                                                                                                                                                                                                                                                                                                                                                                                                      |                                                                                                                                                                                                                                                                     |         return [paren_string[:start_index]]                                                                                                                                                   |
# |              |        |                  |                                       group += char                                                                                                                                                                                                                                                                                                                                                                                                                                  |                                                                                                                                                                                                                                                                     |     res = []                                                                                                                                                                                  |
# |              |        |                  |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |                                                                                                                                                                                                                                                                     |     current = ''                                                                                                                                                                              |
# |              |        |                  |                               # If the character is a closing parenthesis                                                                                                                                                                                                                                                                                                                                                                                                            |                                                                                                                                                                                                                                                                     |     for index in range(start_index + 1, len(paren_string)):                                                                                                                                   |
# |              |        |                  |                               elif char == ')':                                                                                                                                                                                                                                                                                                                                                                                                                                      |                                                                                                                                                                                                                                                                     |         if paren_string[index] == '(':                                                                                                                                                        |
# |              |        |                  |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |                                                                                                                                                                                                                                                                     |             current += paren_string[index]                                                                                                                                                    |
# |              |        |                  |                                   # If the stack is empty, it means the group is not properly closed                                                                                                                                                                                                                                                                                                                                                                                 |                                                                                                                                                                                                                                                                     |         elif paren_string[index] == ')':                                                                                                                                                      |
# |              |        |                  |                                   if not opening_stack:                                                                                                                                                                                                                                                                                                                                                                                                                              |                                                                                                                                                                                                                                                                     |             current += paren_string[index]                                                                                                                                                    |
# |              |        |                  |                                       group = ''                                                                                                                                                                                                                                                                                                                                                                                                                                     |                                                                                                                                                                                                                                                                     |             res.append(current)                                                                                                                                                               |
# |              |        |                  |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |                                                                                                                                                                                                                                                                     |             current = ''                                                                                                                                                                      |
# |              |        |                  |                                   # If the stack is not empty, pop the opening parenthesis from the stack                                                                                                                                                                                                                                                                                                                                                                            |                                                                                                                                                                                                                                                                     |     return res                                                                                                                                                                                |
# |              |        |                  |                                   else:                                                                                                                                                                                                                                                                                                                                                                                                                                              |                                                                                                                                                                                                                                                                     |                                                                                                                                                                                               |
# |              |        |                  |                                       opening_stack.pop()                                                                                                                                                                                                                                                                                                                                                                                                                            |                                                                                                                                                                                                                                                                     |                                                                                                                                                                                               |
# |              |        |                  |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |                                                                                                                                                                                                                                                                     |                                                                                                                                                                                               |
# |              |        |                  |                                   # If the stack is empty, it means the group is properly closed                                                                                                                                                                                                                                                                                                                                                                                     |                                                                                                                                                                                                                                                                     |                                                                                                                                                                                               |
# |              |        |                  |                                   if not opening_stack:                                                                                                                                                                                                                                                                                                                                                                                                                              |                                                                                                                                                                                                                                                                     |                                                                                                                                                                                               |
# |              |        |                  |                                       # Add the group to the list of separate groups                                                                                                                                                                                                                                                                                                                                                                                                 |                                                                                                                                                                                                                                                                     |                                                                                                                                                                                               |
# |              |        |                  |                                       separate_groups.append(group)                                                                                                                                                                                                                                                                                                                                                                                                                  |                                                                                                                                                                                                                                                                     |                                                                                                                                                                                               |
# ...
# |              |        |                  |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |                                                                                                                                                                                                                                                                     |                       def rolling\_max(numbers: List[int]) -> List[int]:                                                                                                                      |
# |              |        |                  |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |                       from typing import List, Tuple                                                                                                                                                                                                                |                                                                                                                                                                                               |
# |              |        |                  |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |                       def rolling\_max(numbers: List[int]) -> List[int]:                                                                                                                                                                                            |                                                                                                                                                                                               |
# |              |        |                  |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |                           :                                                                                                                                                                                                                                         |                                                                                                                                                                                               |
# |              |        |                  |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |                                                                                                                                                                                                                                                                     |                       from typing import List, Tuple                                                                                                                                          |
# |              |        |                  |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |                       from typing import List                                                                                                                                                                                                                       |                       def rolling\_max(numbers: List[int]) -> List[int]:                                                                                                                      |
# |              |        |                  |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |                       def rolling\_max(                                                                                                                                                                                                                             |                                                                                                                                                                                               |
# |              |        |                  |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |                       ):                                                                                                                                                                                                                                            |                                                                                                                                                                                               |
# |              |        |                  |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |                           :                                                                                                                                                                                                                                         |                                                                                                                                                                                               |
# |              |        |                  |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |                                                                                                                                                                                                                                                                     |                       from typing import List, Tuple                                                                                                                                          |
# |              |        |                  |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |                       from typing import List, Tuple                                                                                                                                                                                                                |                       def rolling\_max(numbers: List                                                                                                                                          |
# |              |        |                  |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |                       def rolling\_max(numbers: List[int]) -> List[int]:                                                                                                                                                                                            |                                                                                                                                                                                               |
# |              |        |                  |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |                           :                                                                                                                                                                                                                                         |                                                                                                                                                                                               |
# |              |        |                  |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |                                                                                                                                                                                                                                                                     |                                                                                                                                                                                               |
# |              |        |                  |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |                       from typing import List,                                                                                                                                                                                                                      |                                                                                                                                                                                               |
# +--------------+--------+------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+

# %%
from tabulate import tabulate

detailed_results_table = []

for result in results_all:
  print(result)

  # Go through each problem and candidate
  for problem_id, completions in results.items():
      generation_row = next(item for item in all_generations_table if item["Problem ID"] == problem_id + 1)

      for completion_idx, result_info in completions:
          gen_code = generation_row[f"Gen {completion_idx + 1}"]
          passed = result_info['passed']
          reason = result_info['result']

          detailed_results_table.append({
              "Problem ID": problem_id + 1,
              "LLM": generation_row["LLM"],
              "Prompt Type": generation_row["Prompt Type"],
              "Gen #": f"Gen {completion_idx + 1}",
              "Passed": "✅" if passed else "❌",
              "Reason": reason,
              "Generated Code": gen_code  # truncate long code
          })

# Print table
print("\n=== Detailed Generation Results ===")
print(tabulate(detailed_results_table, headers="keys", tablefmt="fancy_grid"))
# Out:
# defaultdict(<class 'list'>, {0: [(0, {'task_id': 0, 'passed': False, 'result': "failed: name 'List' is not defined", 'completion_id': 0}), (1, {'task_id': 0, 'passed': False, 'result': "failed: name 'List' is not defined", 'completion_id': 1}), (2, {'task_id': 0, 'passed': False, 'result': 'failed: unindent does not match any outer indentation level (<string>, line 11)', 'completion_id': 2})]})
# defaultdict(<class 'list'>, {0: [(0, {'task_id': 0, 'passed': False, 'result': 'failed: unindent does not match any outer indentation level (<string>, line 8)', 'completion_id': 0}), (1, {'task_id': 0, 'passed': False, 'result': "failed: name 'List' is not defined", 'completion_id': 1}), (2, {'task_id': 0, 'passed': False, 'result': "failed: name 'List' is not defined", 'completion_id': 2})]})
# defaultdict(<class 'list'>, {0: [(0, {'task_id': 0, 'passed': False, 'result': 'failed: expected an indented block after function definition on line 1 (<string>, line 4)', 'completion_id': 0}), (1, {'task_id': 0, 'passed': False, 'result': 'failed: unterminated triple-quoted string literal (detected at line 36) (<string>, line 5)', 'completion_id': 1}), (2, {'task_id': 0, 'passed': False, 'result': 'failed: expected an indented block after function definition on line 1 (<string>, line 4)', 'completion_id': 2})]})
# defaultdict(<class 'list'>, {0: [(0, {'task_id': 0, 'passed': False, 'result': 'failed: expected an indented block after function definition on line 1 (<string>, line 4)', 'completion_id': 0}), (1, {'task_id': 0, 'passed': False, 'result': 'failed: invalid syntax (<string>, line 2)', 'completion_id': 1}), (2, {'task_id': 0, 'passed': False, 'result': 'failed: unexpected character after line continuation character (<string>, line 5)', 'completion_id': 2})]})
#
# === Detailed Generation Results ===
# ╒══════════════╤═══════╤══════════════════╤═════════╤══════════╤═══════════════════════════════════════════════════════════════════════════════════════════╤═════════════════════════════════════════════════════════════════════════════════╕
# │   Problem ID │ LLM   │ Prompt Type      │ Gen #   │ Passed   │ Reason                                                                                    │ Generated Code                                                                  │
# ╞══════════════╪═══════╪══════════════════╪═════════╪══════════╪═══════════════════════════════════════════════════════════════════════════════════════════╪═════════════════════════════════════════════════════════════════════════════════╡
# │            1 │ LLaMa │ Chain of Thought │ Gen 1   │ ❌       │ failed: expected an indented block after function definition on line 1 (<string>, line 4) │ def has_close_elements( numbers: List[float], threshold: float) -> bool:        │
# │              │       │                  │         │          │                                                                                           │     numbers.sort()                                                              │
# │              │       │                  │         │          │                                                                                           │     for i in range(1, len(numbers) - 1):                                        │
# │              │       │                  │         │          │                                                                                           │         if numbers[i] - numbers[i - 1] < threshold and numbers[                 │
# │              │       │                  │         │          │                                                                                           │             i + 1] - numbers[i] < threshold:                                    │
# │              │       │                  │         │          │                                                                                           │             return True                                                         │
# │              │       │                  │         │          │                                                                                           │     return False                                                                │
# ├──────────────┼───────┼──────────────────┼─────────┼──────────┼───────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────┤
# │            1 │ LLaMa │ Chain of Thought │ Gen 2   │ ❌       │ failed: invalid syntax (<string>, line 2)                                                 │ def has_close_elements( numbers: List[float], threshold: float) -> bool:        │
# │              │       │                  │         │          │                                                                                           │                                                                                 │
# │              │       │                  │         │          │                                                                                           │                           numbers.sort()                                        │
# │              │       │                  │         │          │                                                                                           │                           for i in range(1, len(numbers) - 1):                  │
# │              │       │                  │         │          │                                                                                           │                               if abs(numbers[i] - numbers[i - 1]) <= threshold: │
# │              │       │                  │         │          │                                                                                           │                                   return True                                   │
# │              │       │                  │         │          │                                                                                           │                           return False                                          │
# │              │       │                  │         │          │                                                                                           │                       return has_close_elements                                 │
# ├──────────────┼───────┼──────────────────┼─────────┼──────────┼───────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────┤
# │            1 │ LLaMa │ Chain of Thought │ Gen 3   │ ❌       │ failed: unexpected character after line continuation character (<string>, line 5)         │ def has_close_elements( numbers: List[float], threshold: float) -> bool:        │
# │              │       │                  │         │          │                                                                                           │                                                                                 │
# │              │       │                  │         │          │                                                                                           │     sorted_numbers = sorted(numbers)                                            │
# │              │       │                  │         │          │                                                                                           │     for i in range(1, len(sorted_numbers)):                                     │
# │              │       │                  │         │          │                                                                                           │         if abs(sorted_numbers[i] - sorted_numbers[i - 1]) < threshold:          │
# │              │       │                  │         │          │                                                                                           │             return True                                                         │
# │              │       │                  │         │          │                                                                                           │     return False                                                                │
# ├──────────────┼───────┼──────────────────┼─────────┼──────────┼───────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────┤
# │            1 │ LLaMa │ Chain of Thought │ Gen 1   │ ❌       │ failed: expected an indented block after function definition on line 1 (<string>, line 4) │ def has_close_elements( numbers: List[float], threshold: float) -> bool:        │
# │              │       │                  │         │          │                                                                                           │     numbers.sort()                                                              │
# │              │       │                  │         │          │                                                                                           │     for i in range(1, len(numbers) - 1):                                        │
# │              │       │                  │         │          │                                                                                           │         if numbers[i] - numbers[i - 1] < threshold and numbers[                 │
# │              │       │                  │         │          │                                                                                           │             i + 1] - numbers[i] < threshold:                                    │
# │              │       │                  │         │          │                                                                                           │             return True                                                         │
# │              │       │                  │         │          │                                                                                           │     return False                                                                │
# ├──────────────┼───────┼──────────────────┼─────────┼──────────┼───────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────┤
# │            1 │ LLaMa │ Chain of Thought │ Gen 2   │ ❌       │ failed: invalid syntax (<string>, line 2)                                                 │ def has_close_elements( numbers: List[float], threshold: float) -> bool:        │
# │              │       │                  │         │          │                                                                                           │                                                                                 │
# │              │       │                  │         │          │                                                                                           │                           numbers.sort()                                        │
# │              │       │                  │         │          │                                                                                           │                           for i in range(1, len(numbers) - 1):                  │
# │              │       │                  │         │          │                                                                                           │                               if abs(numbers[i] - numbers[i - 1]) <= threshold: │
# │              │       │                  │         │          │                                                                                           │                                   return True                                   │
# │              │       │                  │         │          │                                                                                           │                           return False                                          │
# │              │       │                  │         │          │                                                                                           │                       return has_close_elements                                 │
# ├──────────────┼───────┼──────────────────┼─────────┼──────────┼───────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────┤
# │            1 │ LLaMa │ Chain of Thought │ Gen 3   │ ❌       │ failed: unexpected character after line continuation character (<string>, line 5)         │ def has_close_elements( numbers: List[float], threshold: float) -> bool:        │
# │              │       │                  │         │          │                                                                                           │                                                                                 │
# │              │       │                  │         │          │                                                                                           │     sorted_numbers = sorted(numbers)                                            │
# │              │       │                  │         │          │                                                                                           │     for i in range(1, len(sorted_numbers)):                                     │
# │              │       │                  │         │          │                                                                                           │         if abs(sorted_numbers[i] - sorted_numbers[i - 1]) < threshold:          │
# │              │       │                  │         │          │                                                                                           │             return True                                                         │
# │              │       │                  │         │          │                                                                                           │     return False                                                                │
# ├──────────────┼───────┼──────────────────┼─────────┼──────────┼───────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────┤
# │            1 │ LLaMa │ Chain of Thought │ Gen 1   │ ❌       │ failed: expected an indented block after function definition on line 1 (<string>, line 4) │ def has_close_elements( numbers: List[float], threshold: float) -> bool:        │
# │              │       │                  │         │          │                                                                                           │     numbers.sort()                                                              │
# │              │       │                  │         │          │                                                                                           │     for i in range(1, len(numbers) - 1):                                        │
# │              │       │                  │         │          │                                                                                           │         if numbers[i] - numbers[i - 1] < threshold and numbers[                 │
# │              │       │                  │         │          │                                                                                           │             i + 1] - numbers[i] < threshold:                                    │
# │              │       │                  │         │          │                                                                                           │             return True                                                         │
# │              │       │                  │         │          │                                                                                           │     return False                                                                │
# ├──────────────┼───────┼──────────────────┼─────────┼──────────┼───────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────┤
# │            1 │ LLaMa │ Chain of Thought │ Gen 2   │ ❌       │ failed: invalid syntax (<string>, line 2)                                                 │ def has_close_elements( numbers: List[float], threshold: float) -> bool:        │
# │              │       │                  │         │          │                                                                                           │                                                                                 │
# │              │       │                  │         │          │                                                                                           │                           numbers.sort()                                        │
# │              │       │                  │         │          │                                                                                           │                           for i in range(1, len(numbers) - 1):                  │
# │              │       │                  │         │          │                                                                                           │                               if abs(numbers[i] - numbers[i - 1]) <= threshold: │
# │              │       │                  │         │          │                                                                                           │                                   return True                                   │
# │              │       │                  │         │          │                                                                                           │                           return False                                          │
# │              │       │                  │         │          │                                                                                           │                       return has_close_elements                                 │
# ├──────────────┼───────┼──────────────────┼─────────┼──────────┼───────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────┤
# │            1 │ LLaMa │ Chain of Thought │ Gen 3   │ ❌       │ failed: unexpected character after line continuation character (<string>, line 5)         │ def has_close_elements( numbers: List[float], threshold: float) -> bool:        │
# │              │       │                  │         │          │                                                                                           │                                                                                 │
# │              │       │                  │         │          │                                                                                           │     sorted_numbers = sorted(numbers)                                            │
# │              │       │                  │         │          │                                                                                           │     for i in range(1, len(sorted_numbers)):                                     │
# │              │       │                  │         │          │                                                                                           │         if abs(sorted_numbers[i] - sorted_numbers[i - 1]) < threshold:          │
# │              │       │                  │         │          │                                                                                           │             return True                                                         │
# │              │       │                  │         │          │                                                                                           │     return False                                                                │
# ├──────────────┼───────┼──────────────────┼─────────┼──────────┼───────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────┤
# │            1 │ LLaMa │ Chain of Thought │ Gen 1   │ ❌       │ failed: expected an indented block after function definition on line 1 (<string>, line 4) │ def has_close_elements( numbers: List[float], threshold: float) -> bool:        │
# │              │       │                  │         │          │                                                                                           │     numbers.sort()                                                              │
# │              │       │                  │         │          │                                                                                           │     for i in range(1, len(numbers) - 1):                                        │
# │              │       │                  │         │          │                                                                                           │         if numbers[i] - numbers[i - 1] < threshold and numbers[                 │
# │              │       │                  │         │          │                                                                                           │             i + 1] - numbers[i] < threshold:                                    │
# │              │       │                  │         │          │                                                                                           │             return True                                                         │
# │              │       │                  │         │          │                                                                                           │     return False                                                                │
# ├──────────────┼───────┼──────────────────┼─────────┼──────────┼───────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────┤
# │            1 │ LLaMa │ Chain of Thought │ Gen 2   │ ❌       │ failed: invalid syntax (<string>, line 2)                                                 │ def has_close_elements( numbers: List[float], threshold: float) -> bool:        │
# │              │       │                  │         │          │                                                                                           │                                                                                 │
# │              │       │                  │         │          │                                                                                           │                           numbers.sort()                                        │
# │              │       │                  │         │          │                                                                                           │                           for i in range(1, len(numbers) - 1):                  │
# │              │       │                  │         │          │                                                                                           │                               if abs(numbers[i] - numbers[i - 1]) <= threshold: │
# │              │       │                  │         │          │                                                                                           │                                   return True                                   │
# │              │       │                  │         │          │                                                                                           │                           return False                                          │
# │              │       │                  │         │          │                                                                                           │                       return has_close_elements                                 │
# ├──────────────┼───────┼──────────────────┼─────────┼──────────┼───────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────┤
# │            1 │ LLaMa │ Chain of Thought │ Gen 3   │ ❌       │ failed: unexpected character after line continuation character (<string>, line 5)         │ def has_close_elements( numbers: List[float], threshold: float) -> bool:        │
# │              │       │                  │         │          │                                                                                           │                                                                                 │
# │              │       │                  │         │          │                                                                                           │     sorted_numbers = sorted(numbers)                                            │
# │              │       │                  │         │          │                                                                                           │     for i in range(1, len(sorted_numbers)):                                     │
# │              │       │                  │         │          │                                                                                           │         if abs(sorted_numbers[i] - sorted_numbers[i - 1]) < threshold:          │
# │              │       │                  │         │          │                                                                                           │             return True                                                         │
# │              │       │                  │         │          │                                                                                           │     return False                                                                │
# ╘══════════════╧═══════╧══════════════════╧═════════╧══════════╧═══════════════════════════════════════════════════════════════════════════════════════════╧═════════════════════════════════════════════════════════════════════════════════╛

# %%
results_all
# Out:
# [defaultdict(list,
#              {0: [(0,
#                 {'task_id': 0,
#                  'passed': False,
#                  'result': "failed: name 'List' is not defined",
#                  'completion_id': 0}),
#                (1,
#                 {'task_id': 0,
#                  'passed': False,
#                  'result': "failed: name 'List' is not defined",
#                  'completion_id': 1}),
#                (2,
#                 {'task_id': 0,
#                  'passed': False,
#                  'result': 'failed: unindent does not match any outer indentation level (<string>, line 11)',
#                  'completion_id': 2})]}),
#  defaultdict(list,
#              {0: [(0,
#                 {'task_id': 0,
#                  'passed': False,
#                  'result': 'failed: unindent does not match any outer indentation level (<string>, line 8)',
#                  'completion_id': 0}),
#                (1,
#                 {'task_id': 0,
#                  'passed': False,
#                  'result': "failed: name 'List' is not defined",
#                  'completion_id': 1}),
#                (2,
#                 {'task_id': 0,
#                  'passed': False,
#                  'result': "failed: name 'List' is not defined",
#                  'completion_id': 2})]}),
#  defaultdict(list,
#              {0: [(0,
#                 {'task_id': 0,
#                  'passed': False,
#                  'result': 'failed: expected an indented block after function definition on line 1 (<string>, line 4)',
#                  'completion_id': 0}),
#                (1,
#                 {'task_id': 0,
#                  'passed': False,
#                  'result': 'failed: unterminated triple-quoted string literal (detected at line 36) (<string>, line 5)',
#                  'completion_id': 1}),
#                (2,
#                 {'task_id': 0,
#                  'passed': False,
#                  'result': 'failed: expected an indented block after function definition on line 1 (<string>, line 4)',
#                  'completion_id': 2})]}),
#  defaultdict(list,
#              {0: [(0,
#                 {'task_id': 0,
#                  'passed': False,
#                  'result': 'failed: expected an indented block after function definition on line 1 (<string>, line 4)',
#                  'completion_id': 0}),
#                (1,
#                 {'task_id': 0,
#                  'passed': False,
#                  'result': 'failed: invalid syntax (<string>, line 2)',
#                  'completion_id': 1}),
#                (2,
#                 {'task_id': 0,
#                  'passed': False,
#                  'result': 'failed: unexpected character after line continuation character (<string>, line 5)',
#                  'completion_id': 2})]})]
